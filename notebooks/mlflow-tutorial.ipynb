# %%
import lightgbm as lgb
from sklearn import datasets
from sklearn.model_selection import train_test_split
import mlflow
import os

# %%
params = dict(
    test_size=0.2,
    random_state=3,
)
iris = datasets.load_iris()
X, y = iris.data, iris.target
X_train, X_test, y_train, y_test = train_test_split(X, y, **params)

# %%
lgb_params = dict(
    learning_rate=0.05,
    n_estimators=500,
)
model = lgb.LGBMClassifier(**lgb_params)

def mlflow_callback():
    def callback(env):
        for name, loss_name, loss_value, _ in env.evaluation_result_list:
            mlflow.log_metric(key=loss_name, value=loss_value, step=env.iteration)
    return callback

# %%
{**params, **lgb_params}
# Out:
# {'test_size': 0.2,
#  'random_state': 3,
#  'learning_rate': 0.05,
#  'n_estimators': 500}

# %%
mlflow.set_tracking_uri(os.environ["MLFLOW_HOST"])
mlflow.set_experiment("MLMAN-1")
with mlflow.start_run():
    mlflow.log_params(params)
    model.fit(
        X_train,
        y_train,
        eval_set=(X_test, y_test),
        eval_metric=["softmax"],
        callbacks=[
            lgb.early_stopping(10),
            mlflow_callback(),
        ],
    )
# Out:
# [1]	valid_0's multi_logloss: 1.03321
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 0.973349
# [3]	valid_0's multi_logloss: 0.91852
# [4]	valid_0's multi_logloss: 0.867972
# [5]	valid_0's multi_logloss: 0.821192
# [6]	valid_0's multi_logloss: 0.779083
# [7]	valid_0's multi_logloss: 0.738835
# [8]	valid_0's multi_logloss: 0.701313
# [9]	valid_0's multi_logloss: 0.666442
# [10]	valid_0's multi_logloss: 0.633858
# [11]	valid_0's multi_logloss: 0.603301
# [12]	valid_0's multi_logloss: 0.574758
# [13]	valid_0's multi_logloss: 0.548147
# [14]	valid_0's multi_logloss: 0.522459
# [15]	valid_0's multi_logloss: 0.498891
# [16]	valid_0's multi_logloss: 0.476608
# [17]	valid_0's multi_logloss: 0.455254
# [18]	valid_0's multi_logloss: 0.435397
# [19]	valid_0's multi_logloss: 0.416238
# [20]	valid_0's multi_logloss: 0.398951
# [21]	valid_0's multi_logloss: 0.381744
# [22]	valid_0's multi_logloss: 0.366271
# [23]	valid_0's multi_logloss: 0.35123
# [24]	valid_0's multi_logloss: 0.336757
# [25]	valid_0's multi_logloss: 0.322845
# [26]	valid_0's multi_logloss: 0.310397
# [27]	valid_0's multi_logloss: 0.298235
# [28]	valid_0's multi_logloss: 0.286693
# [29]	valid_0's multi_logloss: 0.275704
# [30]	valid_0's multi_logloss: 0.265617
# [31]	valid_0's multi_logloss: 0.255354
# [32]	valid_0's multi_logloss: 0.246645
# [33]	valid_0's multi_logloss: 0.237661
# [34]	valid_0's multi_logloss: 0.229511
# [35]	valid_0's multi_logloss: 0.221648
# [36]	valid_0's multi_logloss: 0.213909
# [37]	valid_0's multi_logloss: 0.206761
# [94]	valid_0's multi_logloss: 0.0639187
# [95]	valid_0's multi_logloss: 0.0629326
# [96]	valid_0's multi_logloss: 0.0619055
# [97]	valid_0's multi_logloss: 0.0611252
# [98]	valid_0's multi_logloss: 0.0602614
# [99]	valid_0's multi_logloss: 0.0595222
# [100]	valid_0's multi_logloss: 0.0587914
# [101]	valid_0's multi_logloss: 0.0580153
# [102]	valid_0's multi_logloss: 0.0573555
# [103]	valid_0's multi_logloss: 0.0567812
# [104]	valid_0's multi_logloss: 0.0561496
# [105]	valid_0's multi_logloss: 0.0558879
# [106]	valid_0's multi_logloss: 0.0552356
# [107]	valid_0's multi_logloss: 0.0547496
# [108]	valid_0's multi_logloss: 0.0542078
# [109]	valid_0's multi_logloss: 0.05347
# [110]	valid_0's multi_logloss: 0.0532733
# [111]	valid_0's multi_logloss: 0.0528841
# [112]	valid_0's multi_logloss: 0.0525018
# [113]	valid_0's multi_logloss: 0.0520624
# [114]	valid_0's multi_logloss: 0.0517434
# [115]	valid_0's multi_logloss: 0.0511186
# [116]	valid_0's multi_logloss: 0.0509745
# [117]	valid_0's multi_logloss: 0.0507367
# [118]	valid_0's multi_logloss: 0.050334
# [119]	valid_0's multi_logloss: 0.0500989
# [120]	valid_0's multi_logloss: 0.0499559
# [121]	valid_0's multi_logloss: 0.0495261
# [122]	valid_0's multi_logloss: 0.049194
# [123]	valid_0's multi_logloss: 0.0490985
# [124]	valid_0's multi_logloss: 0.0490301
# [125]	valid_0's multi_logloss: 0.0488702
# [126]	valid_0's multi_logloss: 0.0483019
# [127]	valid_0's multi_logloss: 0.0480812
# [128]	valid_0's multi_logloss: 0.0479662
# [129]	valid_0's multi_logloss: 0.0478457
# [130]	valid_0's multi_logloss: 0.0477488
# [131]	valid_0's multi_logloss: 0.0476718
# [132]	valid_0's multi_logloss: 0.0476602
# [133]	valid_0's multi_logloss: 0.0475688
# [134]	valid_0's multi_logloss: 0.0472482
# [135]	valid_0's multi_logloss: 0.0473369
# [136]	valid_0's multi_logloss: 0.0475003
# [137]	valid_0's multi_logloss: 0.0471672
# [138]	valid_0's multi_logloss: 0.0472683
# [139]	valid_0's multi_logloss: 0.0474099
# [140]	valid_0's multi_logloss: 0.0472894
# [141]	valid_0's multi_logloss: 0.0471678
# [142]	valid_0's multi_logloss: 0.0473406
# [143]	valid_0's multi_logloss: 0.0474536
# [144]	valid_0's multi_logloss: 0.0476258
# [145]	valid_0's multi_logloss: 0.0477724
# [146]	valid_0's multi_logloss: 0.0474542
# [147]	valid_0's multi_logloss: 0.047952
# Early stopping, best iteration is:
# [137]	valid_0's multi_logloss: 0.0471672
